# %% [markdown]
# # Data Type Investigation
#
# ## Issue Identified
# - Current
# Status: All
# columns
# are
# showing as 'object'
# data
# type
# - Expected: Most
# columns
# should
# be
# numeric(float or int) except for categorical variables
#     - Why
# This is a
# Problem:
# 1.
# Object
# datatypes
# consume
# more
# memory
# 2.
# Cannot
# perform
# numerical
# operations
# efficiently
# 3.
# May
# indicate
# the
# data
# was
# loaded
# incorrectly or contains
# string
# representations
# of
# numbers
#
# ## Investigation Plan
# 1.
# First, we
# 'll check a sample of the data to understand how numbers are stored
# 2.
# Then
# create
# a
# plan
# to
# convert
# columns
# to
# appropriate
# data
# types

# %% [markdown]
# # Data Type Investigation
#
# ## Issue Identified
# - Current
# Status: All
# columns
# are
# showing as 'object'
# data
# type
# - Problem
# Discovered: The
# first
# row
# contains
# column
# headers
# that
# should
# be
# column
# names
# - Example: 'ID' is in the
# data
# instead
# of
# being
# a
# column
# name
# - This
# caused
# pandas
# to
# read
# all
# columns as 'object'
# type since the
# first
# row is text
#
# ## Solution Needed
# 1.
# Reload
# the
# data
# properly
# by:
# - Specifying
# that
# the
# first
# row
# should
# be
# used as column
# headers
# - This
# will
# allow
# pandas
# to
# properly
# infer
# numeric
# data
# types
# - Will
# fix
# the
# duplicate
# column
# headers
# we
# 're seeing (Unnamed: 0 vs ID in data)
#
# ## Expected Result
# - ID: Should
# be
# integer
# - LIMIT_BAL: Should
# be
# numeric(float / int)
# - SEX: Should
# be
# integer(categorical)
# - EDUCATION: Should
# be
# integer(categorical)
# - MARRIAGE: Should
# be
# integer(categorical)

# %% [markdown]
# # Data Type Investigation - Detailed Analysis
#
# ## Current Issue
# - Even
# with proper Excel file reading, columns are still showing as 'object' type
# - This
# suggests
# potential
# data
# quality
# issues
# within
# the
# columns
#
# ## Investigation Steps
# 1.
# Check
# for any non - numeric characters in numeric columns
# 2.
# Examine
# specific
# value
# formats in each
# column
# 3.
# Create
# a
# data
# type conversion plan
# for each column
